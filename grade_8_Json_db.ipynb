# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanchoPPasamonte/Quarter3-Codes/blob/main/grade_8_Json_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/JuanchoPPasamonte/Quarter3-Codes/refs/heads/main/students.JSON"
response = requests.get(url)
students = response.json()
print(students)
#make sure the url is the raw file from the github
# Out:
# {'students': [{'id': 1001, 'name': 'Czarina', 'grades': {'Math': 92, 'CS': 88}}, {'id': 1002, 'name': 'Miguel', 'grades': {'Math': 85, 'CS': 90}}]}

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/firebase_key.json")
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://grade-8-json-db1-default-rtdb.asia-southeast1.firebasedatabase.app"
})
print("Firebase connected successfully!")
# Out:
# Firebase connected successfully!

# %%
import firebase_admin

# Check if the default Firebase app exists before attempting to delete it
if firebase_admin._apps and firebase_admin.get_app() is not None:
    firebase_admin.delete_app(firebase_admin.get_app())
    print("Default Firebase app deleted successfully!")
else:
    print("No default Firebase app found to delete.")
# Out:
# Default Firebase app deleted successfully!

# %%
import requests
import json
"""
The 'students' variable is already loaded from the URL in a previous cell.
Therefore, we can directly use the 'students' variable.
"""
data = students
print("JSON file loaded")
ref = db.reference("students")
for student in data["students"]:
    ref.child(str(student["id"])).set(student)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!
